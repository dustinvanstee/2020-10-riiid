# %%
# !ls
# Out:
# example_sample_submission.csv  nohup.out       riiid-test-answer-prediction.zip
# example_test.csv	       __pycache__     test_exploration.ipynb
# lc_utils_2020.py	       questions.csv   train.csv
# lectures.csv		       riid_eda.ipynb
# LendingClub-AiImmersion.ipynb  riiideducation

# %%
import pandas as pd
df = pd.read_csv('example_test.csv')
df.head(50)
# Out:
#     row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0        0          0            0   275030867        5729                0
# 1        1          0  13309898705   554169193       12010                0
# 2        2          0   4213672059  1720860329         457                0
# 3        3          0  62798072960   288641214       13262                0
# 4        4          0  10585422061  1728340777        6119                0
# 5        5          0  18020362258  1364159702       12023                0
# 6        6          0   2325432079  1521618396         574                0
# 7        7          0  39456940781  1317245193       12043                0
# 8        8          0   3460555189  1700555100        7910                0
# 9        9          0   2214770464   998511398        7908                0
# 10      10          0    516803182  1422853669        1143                0
# ...

# %%
import pandas as pd
df = pd.read_csv('example_sample_submission.csv')
df
# Out:
#      row_id  answered_correctly  group_num
# 0         0                 0.5          0
# 1         1                 0.5          0
# 2         2                 0.5          0
# 3         3                 0.5          0
# 4         4                 0.5          0
# ..      ...                 ...        ...
# 99      104                 0.5          3
# 100     105                 0.5          3
# 101     106                 0.5          3
# 102     107                 0.5          3
# 103     108                 0.5          3
#
# [104 rows x 3 columns]
